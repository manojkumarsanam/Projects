# %%
pip install -qU langchain-google-genai
# Out:
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install langchain_community pypdf
# Out:
# Collecting langchain_community
#   Using cached langchain_community-0.4.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting pypdf
#   Using cached pypdf-6.7.0-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.1 in /Users/manoj/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from langchain_community) (1.2.12)
# Collecting langchain-classic<2.0.0,>=1.0.0 (from langchain_community)
#   Using cached langchain_classic-1.0.1-py3-none-any.whl.metadata (4.2 kB)
# Collecting SQLAlchemy<3.0.0,>=1.4.0 (from langchain_community)
#   Downloading sqlalchemy-2.0.46-cp311-cp311-macosx_11_0_arm64.whl.metadata (9.5 kB)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in /Users/manoj/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from langchain_community) (2.32.5)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in /Users/manoj/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from langchain_community) (6.0.3)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain_community)
#   Downloading aiohttp-3.13.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (8.1 kB)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /Users/manoj/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from langchain_community) (9.1.4)
# Collecting dataclasses-json<0.7.0,>=0.6.7 (from langchain_community)
#   Using cached dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting pydantic-settings<3.0.0,>=2.10.1 (from langchain_community)
#   Using cached pydantic_settings-2.12.0-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in /Users/manoj/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from langchain_community) (0.7.3)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain_community)
#   Using cached httpx_sse-0.4.3-py3-none-any.whl.metadata (9.7 kB)
# Collecting numpy>=1.26.2 (from langchain_community)
#   Downloading numpy-2.4.2-cp311-cp311-macosx_14_0_arm64.whl.metadata (6.6 kB)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Using cached aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting attrs>=17.3.0 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Using cached attrs-25.4.0-py3-none-any.whl.metadata (10 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Downloading frozenlist-1.8.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (20 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Downloading multidict-6.7.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (5.3 kB)
# Collecting propcache>=0.2.0 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Downloading propcache-0.4.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (13 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Downloading yarl-1.22.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.1/75.1 kB 2.4 MB/s eta 0:00:00
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain_community)
#   Using cached marshmallow-3.26.2-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain_community)
#   Using cached typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting langchain-text-splitters<2.0.0,>=1.1.0 (from langchain-classic<2.0.0,>=1.0.0->langchain_community)
#   Using cached langchain_text_splitters-1.1.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/manoj/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain_community) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /Users/manoj/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (1.33)
# Requirement already satisfied: packaging>=23.2.0 in /Users/manoj/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (26.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /Users/manoj/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /Users/manoj/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.0.1->langchain_community) (0.14.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/manoj/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /Users/manoj/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /Users/manoj/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in /Users/manoj/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in /Users/manoj/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.1.125->langchain_community) (0.25.0)
# Collecting python-dotenv>=0.21.0 (from pydantic-settings<3.0.0,>=2.10.1->langchain_community)
#   Using cached python_dotenv-1.2.1-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/manoj/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain_community) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/manoj/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from requests<3.0.0,>=2.32.5->langchain_community) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/manoj/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from requests<3.0.0,>=2.32.5->langchain_community) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/manoj/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from requests<3.0.0,>=2.32.5->langchain_community) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/manoj/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from requests<3.0.0,>=2.32.5->langchain_community) (2026.1.4)
# Requirement already satisfied: anyio in /Users/manoj/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (4.12.1)
# Requirement already satisfied: httpcore==1.* in /Users/manoj/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/manoj/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain_community) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/manoj/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.1->langchain_community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/manoj/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain_community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/manoj/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain_community) (2.41.5)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain_community)
#   Using cached mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Using cached langchain_community-0.4.1-py3-none-any.whl (2.5 MB)
# Using cached pypdf-6.7.0-py3-none-any.whl (330 kB)
# Downloading aiohttp-3.13.3-cp311-cp311-macosx_11_0_arm64.whl (494 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 495.0/495.0 kB 2.9 MB/s eta 0:00:00a 0:00:01
# Using cached dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Using cached httpx_sse-0.4.3-py3-none-any.whl (9.0 kB)
# Using cached langchain_classic-1.0.1-py3-none-any.whl (1.0 MB)
# Downloading numpy-2.4.2-cp311-cp311-macosx_14_0_arm64.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 1.5 MB/s eta 0:00:0000:0100:01
# Using cached pydantic_settings-2.12.0-py3-none-any.whl (51 kB)
# Downloading sqlalchemy-2.0.46-cp311-cp311-macosx_11_0_arm64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 1.9 MB/s eta 0:00:0000:0100:01
# Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Using cached aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Using cached attrs-25.4.0-py3-none-any.whl (67 kB)
# Downloading frozenlist-1.8.0-cp311-cp311-macosx_11_0_arm64.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 kB 2.6 MB/s eta 0:00:00
# Using cached langchain_text_splitters-1.1.0-py3-none-any.whl (34 kB)
# Using cached marshmallow-3.26.2-py3-none-any.whl (50 kB)
# Downloading multidict-6.7.1-cp311-cp311-macosx_11_0_arm64.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 2.3 MB/s eta 0:00:00
# Downloading propcache-0.4.1-cp311-cp311-macosx_11_0_arm64.whl (47 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.6/47.6 kB 2.7 MB/s eta 0:00:00
# Using cached python_dotenv-1.2.1-py3-none-any.whl (21 kB)
# Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading yarl-1.22.0-cp311-cp311-macosx_11_0_arm64.whl (94 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.0/95.0 kB 714.9 kB/s eta 0:00:00a 0:00:01
# Using cached mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Installing collected packages: SQLAlchemy, python-dotenv, pypdf, propcache, numpy, mypy-extensions, multidict, marshmallow, httpx-sse, frozenlist, attrs, aiohappyeyeballs, yarl, typing-inspect, aiosignal, pydantic-settings, dataclasses-json, aiohttp, langchain-text-splitters, langchain-classic, langchain_community
# Successfully installed SQLAlchemy-2.0.46 aiohappyeyeballs-2.6.1 aiohttp-3.13.3 aiosignal-1.4.0 attrs-25.4.0 dataclasses-json-0.6.7 frozenlist-1.8.0 httpx-sse-0.4.3 langchain-classic-1.0.1 langchain-text-splitters-1.1.0 langchain_community-0.4.1 marshmallow-3.26.2 multidict-6.7.1 mypy-extensions-1.1.0 numpy-2.4.2 propcache-0.4.1 pydantic-settings-2.12.0 pypdf-6.7.0 python-dotenv-1.2.1 typing-inspect-0.9.0 yarl-1.22.0
#
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
pip install -qU langchain-pinecone
# Out:
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pinecone
# Out:
# Requirement already satisfied: pinecone in /Users/manoj/.pyenv/versions/3.11.10/lib/python3.11/site-packages (7.3.0)
# Requirement already satisfied: certifi>=2019.11.17 in /Users/manoj/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from pinecone) (2026.1.4)
# Requirement already satisfied: pinecone-plugin-assistant<2.0.0,>=1.6.0 in /Users/manoj/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from pinecone) (1.8.0)
# Requirement already satisfied: pinecone-plugin-interface<0.0.8,>=0.0.7 in /Users/manoj/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from pinecone) (0.0.7)
# Requirement already satisfied: python-dateutil>=2.5.3 in /Users/manoj/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from pinecone) (2.9.0.post0)
# Requirement already satisfied: typing-extensions>=3.7.4 in /Users/manoj/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from pinecone) (4.15.0)
# Requirement already satisfied: urllib3>=1.26.0 in /Users/manoj/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from pinecone) (2.6.3)
# Requirement already satisfied: packaging<25.0,>=24.2 in /Users/manoj/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from pinecone-plugin-assistant<2.0.0,>=1.6.0->pinecone) (24.2)
# Requirement already satisfied: requests<3.0.0,>=2.32.3 in /Users/manoj/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from pinecone-plugin-assistant<2.0.0,>=1.6.0->pinecone) (2.32.5)
# Requirement already satisfied: six>=1.5 in /Users/manoj/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from python-dateutil>=2.5.3->pinecone) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/manoj/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from requests<3.0.0,>=2.32.3->pinecone-plugin-assistant<2.0.0,>=1.6.0->pinecone) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/manoj/.pyenv/versions/3.11.10/lib/python3.11/site-packages (from requests<3.0.0,>=2.32.3->pinecone-plugin-assistant<2.0.0,>=1.6.0->pinecone) (3.11)
#
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install -qU langchain langchain-anthropic
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in /Users/manoj/.pyenv/versions/3.11.10/lib/python3.11/site-packages (24.0)
# Collecting pip
#   Using cached pip-26.0.1-py3-none-any.whl.metadata (4.7 kB)
# Using cached pip-26.0.1-py3-none-any.whl (1.8 MB)
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 24.0
#     Uninstalling pip-24.0:
#       Successfully uninstalled pip-24.0
# Successfully installed pip-26.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from langchain_anthropic import ChatAnthropic
from langchain.agents import create_agent
from dataclasses import dataclass
from langchain.tools import tool, ToolRuntime
from langgraph.checkpoint.memory import InMemorySaver
from langchain.agents.structured_output import ToolStrategy

# %%
from dotenv import load_dotenv

# Load the environment variables from .env file
load_dotenv()

# Now you can access the environment variable just like before
ANTHROPIC_API_KEY = os.environ.get('ANTHROPIC_API_KEY')
LANGSMITH_API_KEY = os.environ.get('LANGSMITH_API_KEY')
LANGSMITH_TRACING="true"
GOOGLE_API_KEY = os.environ.get('GOOGLE_API_KEY')
PINECONE_API_KEY = os.environ.get('PINECONE_API_KEY')

# %%
from langchain_core.documents import Document

documents = [
    Document(
        page_content="Dogs are great companions, known for their loyalty and friendliness.",
        metadata={"source": "mammal-pets-doc"},
    ),
    Document(
        page_content="Cats are independent pets that often enjoy their own space.",
        metadata={"source": "mammal-pets-doc"},
    ),
]

# %%
from langchain_community.document_loaders import PyPDFLoader
file_path = "./example_data/nke-10k-2023.pdf"
loader = PyPDFLoader(file_path)

docs = loader.load()

print(len(docs))
# Out:
# 107

# %%
print(f"{docs[0].page_content[:200]}\n")
print(docs[0].metadata)
# Out:
# Table of Contents
# UNITED STATES
# SECURITIES AND EXCHANGE COMMISSION
# Washington, D.C. 20549
# FORM 10-K
# (Mark One)
# ☑ ANNUAL REPORT PURSUANT TO SECTION 13 OR 15(D) OF THE SECURITIES EXCHANGE ACT OF 1934
# FO
#
# {'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0', 'creator': 'EDGAR Filing HTML Converter', 'creationdate': '2023-07-20T16:22:00-04:00', 'title': '0000320187-23-000039', 'author': 'EDGAR Online, a division of Donnelley Financial Solutions', 'subject': 'Form 10-K filed on 2023-07-20 for the period ending 2023-05-31', 'keywords': '0000320187-23-000039; ; 10-K', 'moddate': '2023-07-20T16:22:08-04:00', 'source': './example_data/nke-10k-2023.pdf', 'total_pages': 107, 'page': 0, 'page_label': '1'}

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000, chunk_overlap=200, add_start_index=True
)
all_splits = text_splitter.split_documents(docs)

print(len(all_splits))
# Out:
# 516

# %%
from langchain_google_genai import GoogleGenerativeAIEmbeddings

embeddings = GoogleGenerativeAIEmbeddings(model="models/gemini-embedding-001")

# %%
vector_1 = embeddings.embed_query(all_splits[0].page_content)
vector_2 = embeddings.embed_query(all_splits[1].page_content)

assert len(vector_1) == len(vector_2)
print(f"Generated vectors of length {len(vector_1)}\n")
print(vector_1[:10])
# Out:
# Generated vectors of length 3072
#
# [0.0028428142, -0.0102483705, 0.0021823694, -0.025355693, -0.010879941, -0.0044366363, 0.012312499, -0.02148518, -0.013332739, 0.010780239]

# %%
from langchain_pinecone import PineconeVectorStore
from pinecone import Pinecone

pc = Pinecone(api_key=PINECONE_API_KEY)
index = pc.Index("index1")

vector_store = PineconeVectorStore(embedding=embeddings, index=index)

# %%
ids = vector_store.add_documents(documents=all_splits)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# File ~/.pyenv/versions/3.11.10/lib/python3.11/site-packages/langchain_google_genai/embeddings.py:432, in GoogleGenerativeAIEmbeddings.embed_documents(self, texts, batch_size, task_type, titles, output_dimensionality)
#     431 try:
# --> 432     result = self.client.models.embed_content(
#     433         model=self.model,
#     434         contents=batch,
#     435         config=config,
#     436     )
#     437 except ClientError as e:
#
# File ~/.pyenv/versions/3.11.10/lib/python3.11/site-packages/google/genai/models.py:4404, in Models.embed_content(self, model, contents, config)
#    4402 request_dict = _common.encode_unserializable_types(request_dict)
# -> 4404 response = self._api_client.request(
#    4405     'post', path, request_dict, http_options
#    4406 )
#    4408 response_dict = {} if not response.body else json.loads(response.body)
#
# File ~/.pyenv/versions/3.11.10/lib/python3.11/site-packages/google/genai/_api_client.py:1396, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1393 http_request = self._build_request(
#    1394     http_method, path, request_dict, http_options
#    1395 )
# -> 1396 response = self._request(http_request, http_options, stream=False)
#    1397 response_body = (
#    1398     response.response_stream[0] if response.response_stream else ''
#    1399 )
#
# File ~/.pyenv/versions/3.11.10/lib/python3.11/site-packages/google/genai/_api_client.py:1232, in BaseApiClient._request(self, http_request, http_options, stream)
#    1230     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
# -> 1232 return self._retry(self._request_once, http_request, stream)
#
# File ~/.pyenv/versions/3.11.10/lib/python3.11/site-packages/tenacity/__init__.py:470, in Retrying.__call__(self, fn, *args, **kwargs)
#     469 while True:
# --> 470     do = self.iter(retry_state=retry_state)
#     471     if isinstance(do, DoAttempt):
#
# File ~/.pyenv/versions/3.11.10/lib/python3.11/site-packages/tenacity/__init__.py:371, in BaseRetrying.iter(self, retry_state)
#     370 for action in self.iter_state.actions:
# --> 371     result = action(retry_state)
#     372 return result
#
# File ~/.pyenv/versions/3.11.10/lib/python3.11/site-packages/tenacity/__init__.py:413, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     412 if self.reraise:
# --> 413     raise retry_exc.reraise()
#     414 raise retry_exc from fut.exception()
#
# File ~/.pyenv/versions/3.11.10/lib/python3.11/site-packages/tenacity/__init__.py:184, in RetryError.reraise(self)
#     183 if self.last_attempt.failed:
# --> 184     raise self.last_attempt.result()
#     185 raise self
#
# File ~/.pyenv/versions/3.11.10/lib/python3.11/concurrent/futures/_base.py:449, in Future.result(self, timeout)
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#
# File ~/.pyenv/versions/3.11.10/lib/python3.11/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     400 try:
# --> 401     raise self._exception
#     402 finally:
#     403     # Break a reference cycle with the exception in self._exception
#
# File ~/.pyenv/versions/3.11.10/lib/python3.11/site-packages/tenacity/__init__.py:473, in Retrying.__call__(self, fn, *args, **kwargs)
#     472 try:
# --> 473     result = fn(*args, **kwargs)
#     474 except BaseException:  # noqa: B902
#
# File ~/.pyenv/versions/3.11.10/lib/python3.11/site-packages/google/genai/_api_client.py:1209, in BaseApiClient._request_once(self, http_request, stream)
#    1202 response = self._httpx_client.request(
#    1203     method=http_request.method,
#    1204     url=http_request.url,
#    (...)   1207     timeout=http_request.timeout,
#    1208 )
# -> 1209 errors.APIError.raise_for_response(response)
#    1210 return HttpResponse(
#    1211     response.headers, response if stream else [response.text]
#    1212 )
#
# File ~/.pyenv/versions/3.11.10/lib/python3.11/site-packages/google/genai/errors.py:134, in APIError.raise_for_response(cls, response)
#     132   response_json = response.body_segments[0].get('error', {})
# --> 134 cls.raise_error(response.status_code, response_json, response)
#
# File ~/.pyenv/versions/3.11.10/lib/python3.11/site-packages/google/genai/errors.py:159, in APIError.raise_error(cls, status_code, response_json, response)
#     158 if 400 <= status_code < 500:
# --> 159   raise ClientError(status_code, response_json, response)
#     160 elif 500 <= status_code < 600:
#
# ClientError: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/embed_content_free_tier_requests, limit: 100, model: gemini-embedding-1.0\nPlease retry in 45.631684082s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/embed_content_free_tier_requests', 'quotaId': 'EmbedContentRequestsPerMinutePerUserPerProjectPerModel-FreeTier', 'quotaDimensions': {'model': 'gemini-embedding-1.0', 'location': 'global'}, 'quotaValue': '100'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '45s'}]}}
#
# The above exception was the direct cause of the following exception:
#
# GoogleGenerativeAIError                   Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 ids = vector_store.add_documents(documents=all_splits)
#
# File ~/.pyenv/versions/3.11.10/lib/python3.11/site-packages/langchain_core/vectorstores/base.py:258, in VectorStore.add_documents(self, documents, **kwargs)
#     256     texts = [doc.page_content for doc in documents]
#     257     metadatas = [doc.metadata for doc in documents]
# --> 258     return self.add_texts(texts, metadatas, **kwargs)
#     259 msg = (
#     260     f"`add_documents` and `add_texts` has not been implemented "
#     261     f"for {self.__class__.__name__} "
#     262 )
#     263 raise NotImplementedError(msg)
#
# File ~/.pyenv/versions/3.11.10/lib/python3.11/site-packages/langchain_pinecone/vectorstores.py:357, in PineconeVectorStore.add_texts(self, texts, metadatas, ids, namespace, batch_size, embedding_chunk_size, async_req, id_prefix, **kwargs)
#     355 chunk_ids = ids[i : i + embedding_chunk_size]
#     356 chunk_metadatas = metadatas[i : i + embedding_chunk_size]
# --> 357 embeddings = self._embedding.embed_documents(chunk_texts)
#     358 vector_tuples = list(zip(chunk_ids, embeddings, chunk_metadatas))
#     359 if async_req:
#     360     # Runs the pinecone upsert asynchronously.
#
# File ~/.pyenv/versions/3.11.10/lib/python3.11/site-packages/langchain_google_genai/embeddings.py:439, in GoogleGenerativeAIEmbeddings.embed_documents(self, texts, batch_size, task_type, titles, output_dimensionality)
#     437 except ClientError as e:
#     438     msg = f"Error embedding content ({e.status}): {e}"
# --> 439     raise GoogleGenerativeAIError(msg) from e
#     440 except Exception as e:
#     441     msg = f"Error embedding content: {e}"
#
# GoogleGenerativeAIError: Error embedding content (RESOURCE_EXHAUSTED): 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/embed_content_free_tier_requests, limit: 100, model: gemini-embedding-1.0\nPlease retry in 45.631684082s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/embed_content_free_tier_requests', 'quotaId': 'EmbedContentRequestsPerMinutePerUserPerProjectPerModel-FreeTier', 'quotaDimensions': {'model': 'gemini-embedding-1.0', 'location': 'global'}, 'quotaValue': '100'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '45s'}]}}

# %%
import time

# 1. Define your batch size (e.g., 50 chunks at a time)
batch_size = 50 

# 2. Loop through your document splits in batches
for i in range(0, len(all_splits), batch_size):
    batch = all_splits[i : i + batch_size]
    
    # Add the current batch to Pinecone
    vector_store.add_documents(documents=batch)
    
    # 3. Pause for 60 seconds to reset your "Requests Per Minute" quota
    print(f"Uploaded batch {i//batch_size + 1}. Sleeping for 60s...")
    time.sleep(30)
# Out:
# Uploaded batch 1. Sleeping for 60s...
# Uploaded batch 2. Sleeping for 60s...
# Uploaded batch 3. Sleeping for 60s...
# Uploaded batch 4. Sleeping for 60s...
# Uploaded batch 5. Sleeping for 60s...
# Uploaded batch 6. Sleeping for 60s...
# Uploaded batch 7. Sleeping for 60s...
# Uploaded batch 8. Sleeping for 60s...
# Uploaded batch 9. Sleeping for 60s...
# Uploaded batch 10. Sleeping for 60s...
# Uploaded batch 11. Sleeping for 60s...

# %%
results = vector_store.similarity_search(
    "How many distribution centers does Nike have in the US?"
)

print(results[0])
# Out:
# page_content='operations. We also lease an office complex in Shanghai, China, our headquarters for our Greater China geography, occupied by employees focused on implementing our
# wholesale, NIKE Direct and merchandising strategies in the region, among other functions.
# In the United States, NIKE has eight significant distribution centers. Five are located in or near Memphis, Tennessee, two of which are owned and three of which are
# leased. Two other distribution centers, one located in Indianapolis, Indiana and one located in Dayton, Tennessee, are leased and operated by third-party logistics
# providers. One distribution center for Converse is located in Ontario, California, which is leased. NIKE has a number of distribution facilities outside the United States,
# some of which are leased and operated by third-party logistics providers. The most significant distribution facilities outside the United States are located in Laakdal,' metadata={'author': 'EDGAR Online, a division of Donnelley Financial Solutions', 'creationdate': '2023-07-20T16:22:00-04:00', 'creator': 'EDGAR Filing HTML Converter', 'keywords': '0000320187-23-000039; ; 10-K', 'moddate': '2023-07-20T16:22:08-04:00', 'page': 26.0, 'page_label': '27', 'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0', 'source': './example_data/nke-10k-2023.pdf', 'start_index': 804.0, 'subject': 'Form 10-K filed on 2023-07-20 for the period ending 2023-05-31', 'title': '0000320187-23-000039', 'total_pages': 107.0}

# %%
results = await vector_store.asimilarity_search("When was Nike incorporated?")

print(results[0])
# Out:
# page_content='Table of Contents
# PART I
# ITEM 1. BUSINESS
# GENERAL
# NIKE, Inc. was incorporated in 1967 under the laws of the State of Oregon. As used in this Annual Report on Form 10-K (this "Annual Report"), the terms "we," "us," "our,"
# "NIKE" and the "Company" refer to NIKE, Inc. and its predecessors, subsidiaries and affiliates, collectively, unless the context indicates otherwise.
# Our principal business activity is the design, development and worldwide marketing and selling of athletic footwear, apparel, equipment, accessories and services. NIKE is
# the largest seller of athletic footwear and apparel in the world. We sell our products through NIKE Direct operations, which are comprised of both NIKE-owned retail stores
# and sales through our digital platforms (also referred to as "NIKE Brand Digital"), to retail accounts and to a mix of independent distributors, licensees and sales' metadata={'author': 'EDGAR Online, a division of Donnelley Financial Solutions', 'creationdate': '2023-07-20T16:22:00-04:00', 'creator': 'EDGAR Filing HTML Converter', 'keywords': '0000320187-23-000039; ; 10-K', 'moddate': '2023-07-20T16:22:08-04:00', 'page': 3.0, 'page_label': '4', 'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0', 'source': './example_data/nke-10k-2023.pdf', 'start_index': 0.0, 'subject': 'Form 10-K filed on 2023-07-20 for the period ending 2023-05-31', 'title': '0000320187-23-000039', 'total_pages': 107.0}

# %%
# Note that providers implement different scores; the score here
# is a distance metric that varies inversely with similarity.

results = vector_store.similarity_search_with_score("What was Nike's revenue in 2023?")
doc, score = results[0]
print(f"Score: {score}\n")
print(doc)
# Out:
# Score: 0.77178967
#
# page_content='Table of Contents
# FISCAL 2023 NIKE BRAND REVENUE HIGHLIGHTSThe following tables present NIKE Brand revenues disaggregated by reportable operating segment, distribution channel and major product line:
# FISCAL 2023 COMPARED TO FISCAL 2022
# • NIKE, Inc. Revenues were $51.2 billion in fiscal 2023, which increased 10% and 16% compared to fiscal 2022 on a reported and currency-neutral basis, respectively.
# The increase was due to higher revenues in North America, Europe, Middle East & Africa ("EMEA"), APLA and Greater China, which contributed approximately 7, 6,
# 2 and 1 percentage points to NIKE, Inc. Revenues, respectively.
# • NIKE Brand revenues, which represented over 90% of NIKE, Inc. Revenues, increased 10% and 16% on a reported and currency-neutral basis, respectively. This
# increase was primarily due to higher revenues in Men's, the Jordan Brand, Women's and Kids' which grew 17%, 35%,11% and 10%, respectively, on a wholesale
# equivalent basis.' metadata={'author': 'EDGAR Online, a division of Donnelley Financial Solutions', 'creationdate': '2023-07-20T16:22:00-04:00', 'creator': 'EDGAR Filing HTML Converter', 'keywords': '0000320187-23-000039; ; 10-K', 'moddate': '2023-07-20T16:22:08-04:00', 'page': 35.0, 'page_label': '36', 'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0', 'source': './example_data/nke-10k-2023.pdf', 'start_index': 0.0, 'subject': 'Form 10-K filed on 2023-07-20 for the period ending 2023-05-31', 'title': '0000320187-23-000039', 'total_pages': 107.0}

# %%
embedding = embeddings.embed_query("How were Nike's margins impacted in 2023?")

results = vector_store.similarity_search_by_vector(embedding)
print(results[0])
# Out:
# page_content='Table of Contents
# GROSS MARGIN
# FISCAL 2023 COMPARED TO FISCAL 2022
# For fiscal 2023, our consolidated gross profit increased 4% to $22,292 million compared to $21,479 million for fiscal 2022. Gross margin decreased 250 basis points to
# 43.5% for fiscal 2023 compared to 46.0% for fiscal 2022 due to the following:
# *Wholesale equivalent
# The decrease in gross margin for fiscal 2023 was primarily due to:
# • Higher NIKE Brand product costs, on a wholesale equivalent basis, primarily due to higher input costs and elevated inbound freight and logistics costs as well as
# product mix;
# • Lower margin in our NIKE Direct business, driven by higher promotional activity to liquidate inventory in the current period compared to lower promotional activity in
# the prior period resulting from lower available inventory supply;
# • Unfavorable changes in net foreign currency exchange rates, including hedges; and
# • Lower off-price margin, on a wholesale equivalent basis.
# This was partially offset by:' metadata={'author': 'EDGAR Online, a division of Donnelley Financial Solutions', 'creationdate': '2023-07-20T16:22:00-04:00', 'creator': 'EDGAR Filing HTML Converter', 'keywords': '0000320187-23-000039; ; 10-K', 'moddate': '2023-07-20T16:22:08-04:00', 'page': 36.0, 'page_label': '37', 'producer': 'EDGRpdf Service w/ EO.Pdf 22.0.40.0', 'source': './example_data/nke-10k-2023.pdf', 'start_index': 0.0, 'subject': 'Form 10-K filed on 2023-07-20 for the period ending 2023-05-31', 'title': '0000320187-23-000039', 'total_pages': 107.0}
